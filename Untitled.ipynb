# %%
import tensorflow as tf
import matplotlib.pyplot as plt
from IPython.display import HTML
from tensorflow.keras import models, layers

BATCH_SIZE = 32
IMAGE_SIZE = 27
CHANNELS=24
EPOCHS=50

# %%
# !pip install glob2
# Out:
# ...
#   Created wheel for glob2: filename=glob2-0.7-py2.py3-none-any.whl size=9324 sha256=70258d9b7f9b700b01393cbcffed4714466cefff734c0b8191a47af805287482
#   Stored in directory: c:\users\ngo quang khai\appdata\local\pip\cache\wheels\c0\dd\ee\ba6164807de7570971e8f160dbe6a4178ff4e5922f48c093be
# Successfully built glob2
# ...

# %%
dataset= tf.keras.preprocessing.image_dataset_from_directory(
    "patch_images/task1",
    seed=123,
    image_size=(IMAGE_SIZE,IMAGE_SIZE),
    batch_size=BATCH_SIZE
)
# Out:
# Found 9896 files belonging to 4 classes.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [38], in <cell line: 1>()
# ----> 1 dataset, train_paths= tf.keras.preprocessing.image_dataset_from_directory(
#       2     "patch_images/task1",
#       3     seed=123,
#       4     image_size=(IMAGE_SIZE,IMAGE_SIZE),
#       5     batch_size=BATCH_SIZE
#       6 )
#
# ValueError: too many values to unpack (expected 2)

# %%
class_names = dataset.class_names
class_names
# Out:
# ['epithelial', 'fibroblast', 'inflammatory', 'others']

# %%
from glob2 import glob

files = glob('patch_images/*/*.jpg')

def load(path):
    as_string = tf.io.read_file(path)
    as_image = tf.image.decode_image(as_string, channels=3)
    resized = tf.image.resize(as_image, (224, 224))
    normalized = tf.divide(resized, 255)
    return normalized, path

ds = tf.data.Dataset.from_tensor_slices(files).shuffle(32)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [20], in <cell line: 12>()
#       9     normalized = tf.divide(resized, 255)
#      10     return normalized, path
# ---> 12 ds = tf.data.Dataset.from_tensor_slices(files).shuffle(32).map(load)
#
# File D:\Anaconda\envs\tf_gpu\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:1861, in DatasetV2.map(self, map_func, num_parallel_calls, deterministic)
#    1858   if deterministic is not None and not DEBUG_MODE:
#    1859     warnings.warn("The `deterministic` argument has no effect unless the "
#    1860                   "`num_parallel_calls` argument is specified.")
# -> 1861   return MapDataset(self, map_func, preserve_cardinality=True)
#    1862 else:
#    1863   return ParallelMapDataset(
#    1864       self,
#    1865       map_func,
#    1866       num_parallel_calls,
#    1867       deterministic,
# ...

# %%
# Out:
# <TakeDataset shapes: ((None, 27, 27, 3), (None,)), types: (tf.float32, tf.int32)>

# %%
class_names = dataset.class_names
class_names
# Out:
# ['epithelial', 'fibroblast', 'inflammatory', 'others']

# %%
plt.figure(figsize=(10, 10))
for image_batch, labels_batch in dataset.take(1):
    for i in range(12):
        ax = plt.subplot(3, 4, i + 1)
        plt.imshow(image_batch[i].numpy().astype("uint8"))
        plt.title(class_names[labels_batch[i]])
        plt.axis("off")
