# %% [markdown]
# <hr style="border:0.1px solid gray">

# %% [markdown]
# # <center style='color:Red'> COSC2753 - Machine Learning </center>
# ## <center style='color:Red'> Assignment 2 - Classify Images of Colon Cancer </center>

# %% [markdown]
# **Group Number:** 8
#
# **Student 1:** Ngo Quang Khai - s3836387
#
# **Student 2:** Nguyen Quoc Minh - s3758994
#
# **Student 3:** Bui Thanh Huy - s3740934
#
# **Student 4:** Tran Vinh Khang - s3855823
#
# **Student 5:** Le Trong Hung - s3805504
#
# **Lecturer:** Dr. Bao Nguyen
#
# **Due Date:** May 14th, 2021

# %% [markdown]
# <hr style="border:0.1px solid gray">

# %% [markdown]
# # Main Task

# %% [markdown]
# - **Task 1**: Classify images according to whether given cell image represents a cancerous cells or not (isCancerous)
#
#
# - **Task 2**: Classify images according to cell-type, such as: fibroblast, inflammatory, epithelial or others.
#
#
# - **Extra task**:

# %% [markdown]
# # 1. Import libraries and setting up environment

# %%
#!pip install tensorflow
#!pip install keras
#!pip install opencv-python
#!pip install imblearn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 
import seaborn as sns
from tqdm import tqdm

import cv2
import os
import tensorflow as tf
import sklearn as sk

import warnings
warnings.filterwarnings('ignore')


#It is important to check the version of these libraries to make sure that implement the latest method.
print('Tensorflow version:', tf.__version__)
print('CV2 version:', cv2.__version__)
# Out:
# Tensorflow version: 2.8.0
# CV2 version: 4.5.5

# %% [markdown]
# # 2. Import Dataset

# %%
#Import data_labels_mainData.csv into a DataFrame
main_data = pd.read_csv('data_labels_mainData.csv')

#Import data_labels_extraData.csv into a DataFrame
extra_data = pd.read_csv('data_labels_extraData.csv')

# %% [markdown]
# # 3. Exploratory Data Analysis (EDA)

# %% [markdown]
# ## 3.1. Process the data

# %%
#See the data frame of main_data
print("Dataframe of main_data: \n", main_data, "\n")

#See the data frame of extra_data
print("Dataframe of extra_data: \n", extra_data)
# Out:
# Dataframe of main_data:
#        InstanceID  patientID  ImageName cellTypeName  cellType  isCancerous
# 0          22405          1  22405.png   fibroblast         0            0
# 1          22406          1  22406.png   fibroblast         0            0
# 2          22407          1  22407.png   fibroblast         0            0
# 3          22408          1  22408.png   fibroblast         0            0
# 4          22409          1  22409.png   fibroblast         0            0
# ...          ...        ...        ...          ...       ...          ...
# 9891        1625         60   1625.png   epithelial         2            1
# 9892        1626         60   1626.png   epithelial         2            1
# 9893        1627         60   1627.png   epithelial         2            1
# 9894        1628         60   1628.png   epithelial         2            1
# 9895        1629         60   1629.png   epithelial         2            1
#
# [9896 rows x 6 columns]
#
# Dataframe of extra_data:
#         InstanceID  patientID  ImageName  isCancerous
# 0           12681         61  12681.png            0
# 1           12682         61  12682.png            0
# 2           12683         61  12683.png            0
# 3           12684         61  12684.png            0
# 4           12685         61  12685.png            0
# ...           ...        ...        ...          ...
# 10379       20028         99  20028.png            0
# 10380       20029         99  20029.png            0
# 10381       20030         99  20030.png            0
# 10382       20031         99  20031.png            0
# 10383       20032         99  20032.png            0
#
# [10384 rows x 4 columns]

# %% [markdown]
# Next, we will check if the data have any null values and datatype of each columns.

# %%
main_data.info()
main_data.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9896 entries, 0 to 9895
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   InstanceID    9896 non-null   int64
#  1   patientID     9896 non-null   int64
#  2   ImageName     9896 non-null   object
#  3   cellTypeName  9896 non-null   object
#  4   cellType      9896 non-null   int64
#  5   isCancerous   9896 non-null   int64
# dtypes: int64(4), object(2)
# memory usage: 464.0+ KB
# InstanceID      0
# patientID       0
# ImageName       0
# cellTypeName    0
# cellType        0
# isCancerous     0
# dtype: int64

# %%
extra_data.info()
extra_data.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10384 entries, 0 to 10383
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   InstanceID   10384 non-null  int64
#  1   patientID    10384 non-null  int64
#  2   ImageName    10384 non-null  object
#  3   isCancerous  10384 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 324.6+ KB
# InstanceID     0
# patientID      0
# ImageName      0
# isCancerous    0
# dtype: int64

# %% [markdown]
# **=>** Since our data is no missing/null value and properly formatted, we will move on to analyzing data.

# %% [markdown]
# Because we don't need columns InstanceID and patientID to train the models, so we are going to drop them.

# %%
#Drop 2 columns InstanceID and patientID for main_data
main_data = main_data.drop(['InstanceID', 'patientID'], axis='columns')

#Drop 2 columns InstanceID and patientID for extra_data
extra_data = extra_data.drop(['InstanceID', 'patientID'], axis='columns')

#See the dataframe of main_data and extra_data after drop 2 columns InstanceID and patientID
print("Dataframe of main_data after drop : \n", main_data, "\n")
print("Dataframe of extra_data after drop: \n", extra_data)
# Out:
# Dataframe of main_data after drop :
#        ImageName cellTypeName  cellType  isCancerous
# 0     22405.png   fibroblast         0            0
# 1     22406.png   fibroblast         0            0
# 2     22407.png   fibroblast         0            0
# 3     22408.png   fibroblast         0            0
# 4     22409.png   fibroblast         0            0
# ...         ...          ...       ...          ...
# 9891   1625.png   epithelial         2            1
# 9892   1626.png   epithelial         2            1
# 9893   1627.png   epithelial         2            1
# 9894   1628.png   epithelial         2            1
# 9895   1629.png   epithelial         2            1
#
# [9896 rows x 4 columns]
#
# Dataframe of extra_data after drop:
#         ImageName  isCancerous
# 0      12681.png            0
# 1      12682.png            0
# 2      12683.png            0
# 3      12684.png            0
# 4      12685.png            0
# ...          ...          ...
# 10379  20028.png            0
# 10380  20029.png            0
# 10381  20030.png            0
# 10382  20031.png            0
# 10383  20032.png            0
#
# [10384 rows x 2 columns]

# %% [markdown]
# ## 3.2. Data Analysis and Visualiztion

# %% [markdown]
# Based on the information provided by the biomedical company as well as the DataFrames in **section 3.1** above. We are aware of:
# - The **main_data** contains both **cellType (0 to 3)** and **isCancerous (0 and 1)** columns. In there, **cellType** values 0 to 3 represent fibroblast, inflammatory, epithelial, and miscellaneous cell types respectively based on the **cellTypeName** column. In addition, **isCancerous** values 0 and 1 represent colon cells with non-Cancer and Cancer.
#
#
# - The **extra_data** only contains **isCancerous (0 and 1)** column.
#
# **=>** Therefore, we choose the **isCancerous** attribute as the target column because both **main_data** and **extra_data** have the column **isCancerous**.

# %% [markdown]
# ### 3.2.1. Data Distribution

# %% [markdown]
# ### Countplot

# %%
#Using the countplot to see the classification of cellType and isCancerous 
fig, ax =plt.subplots(1,2, figsize = (12,6))

# 0 = fibroblast, 1 = imflammatory, 2 = epithelial, 3 = others
sns.countplot(main_data['cellType'], palette='Set2', ax=ax[0]).set_title("Classification of Cell Types")

sns.countplot(main_data['isCancerous'], palette='Set1', ax=ax[1]).set_title("Classification of Cells isCancerous and Non-Cancerous")
fig.show()

# %% [markdown]
# **Analysis**
# - The first countplot shows us there 4 different types of cell: 0, 1, 2, 3. The first type of cell is 0 has approximately 1900, the second type of cell is 2 has approximately 2600, the third one is 4100 and last one is 1500.
#
#
# - The second countplot shows us number of cells that are cancer and not. In the first column is 0 represent the cell that are not cancerous, and 1 represent the cell that are cancerous. There are approximately 5900 cells that are not cancerous and 4200 cells that are cancerous in our data.

# %% [markdown]
# ### Histogram

# %%
# Draw the histogram for cellType respected to isCancerous (class 0 and 1)
g = sns.FacetGrid(main_data, col='isCancerous', height=4, aspect=2)
g.map(plt.hist, str('cellType'), bins=20)
g.set_axis_labels('cellType', "Count")

# %% [markdown]
# **Analysis**
#
# Looking at these two histograms, we can see that 'cellType' 0, 1, and 3 are not cancerous. Meanwhile only 'cellType' 2 is cancerous.

# %%
# Apply loc to double check that only cellType = 2 is Cancerous
main_data.loc[(main_data['cellType'] == 2) & (main_data['isCancerous'] == 1)]
# Out:
#      ImageName cellTypeName  cellType  isCancerous
# 449    276.png   epithelial         2            1
# 450    277.png   epithelial         2            1
# 451    278.png   epithelial         2            1
# 452    279.png   epithelial         2            1
# 453    280.png   epithelial         2            1
# ...        ...          ...       ...          ...
# 9891  1625.png   epithelial         2            1
# 9892  1626.png   epithelial         2            1
# 9893  1627.png   epithelial         2            1
# 9894  1628.png   epithelial         2            1
# 9895  1629.png   epithelial         2            1
#
# [4079 rows x 4 columns]

# %% [markdown]
# ### Conclusion
#
# - In **main_data**, only the attribute **cellType** continue to be our strongest candidate for to influence our model when it has high impact on our target attribute is **isCancerous**.
#
#
# - Attributes such as **InstanceID** and **patientID** might create a lot of noise in our model.
#
#
# - There are 4 types of cells: 0, 1, 2, 3. Only cell type number 2 is cancerous while others are not cancerous.
#
#
# - We expect the the model would predict class 0 more accurately than class 1

# %% [markdown]
# ## 3.3. Data Preparation

# %% [markdown]
# ### 3.1 Split data into train and validation set

# %%
from sklearn.model_selection import train_test_split

#splitting data into train and validation 
train_task1, val_task1 = train_test_split(main_data[['ImageName', 'isCancerous']], 
                                              test_size=0.2, random_state=9)


train_task2, val_task2 = train_test_split(main_data[['ImageName','cellType']], 
                                              test_size=0.2, random_state=9)                                        

print('Training data shape task 1:', train_task1.shape)
print('Validation data shape task 1:', val_task1.shape)

print('Training data shape task 2:', train_task2.shape)
print('Validation data shape task 2:', val_task2.shape)
# Out:
# Training data shape task 1: (7916, 2)
# Validation data shape task 1: (1980, 2)
# Training data shape task 2: (7916, 2)
# Validation data shape task 2: (1980, 2)

# %% [markdown]
# ### 3.2. Create sample image to balance among classes (Oversampling Technique)

# %%
from tensorflow import keras
from tensorflow.keras import layers

data_augmentation = keras.Sequential(
  [
    layers.experimental.preprocessing.RandomRotation(0.1),
    layers.experimental.preprocessing.RandomZoom(0.1),
  ]
)
#Create a a function to add image according to the name given from the list
from PIL import Image
def GetImage(training_dataset):
    images=[]
    unique = []
    for name in tqdm(training_dataset, desc="Adding images"):
        if name not in unique:
            image = cv2.imread("patch_images/"+name)
            image = Image.fromarray(image,'RGB')
            images.append(np.array(image))
            unique.append(name)
        else:
            image = cv2.imread("patch_images/"+name)
            image = Image.fromarray(image,'RGB')
            image = data_augmentation(image)
            images.append(np.array(image))

    result = np.array(images)
    print("\ngetImage COMPLETED!")
    return result

# %% [markdown]
# sai dòng 3 (directory) bởi vù nó chỉ muốn lấy data từ folder hình ảnh

# %%
#Create a function to generate sample to fix the Imblance of the dataset
from imblearn.over_sampling import RandomOverSampler
def GenerateSample(X,Y):
    ros = RandomOverSampler(random_state = 1)
    x, y = ros.fit_resample(X.values.reshape(-1,1), Y)
    x = x.flatten()
    return x,y

# %%
x1_train = train_task1['ImageName']
y1_train = train_task1['isCancerous']
print("Original Dataset:\n",y1_train.value_counts())

#Generate sample
x1_train, y1_train = GenerateSample(x1_train,y1_train)
print("Sampled Dataset:\n",y1_train.value_counts())
x1_train = GetImage(x1_train)

x1_test = val_task1['ImageName']
x1_test = GetImage(x1_test)

y1_test = val_task1['isCancerous']
# Out:
# Original Dataset:
#  0    4634
# 1    3282
# Name: isCancerous, dtype: int64
# Sampled Dataset:
#  0    4634
# 1    4634
# Name: isCancerous, dtype: int64
# Adding images:  82%|██████████████████████████████████████████████████▏          | 7634/9268 [00:01<00:00, 3752.21it/s]
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20857740790>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086D0067C0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086D006E20>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20857740790>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086D006E20>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086D006E20>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20857740790>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086D006E20>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086D0067C0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20857740790>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086D0067C0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086D006CA0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20857740790>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086D006CA0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086D006E20>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20857740790>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20857740790>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086D006E20>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C29B50>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086D0067C0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C29B50>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086D0067C0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C29C10>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086D006E20>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C29B50>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086D006CA0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C29C10>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086D0067C0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C29B50>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086D0067C0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C29C10>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086D006CA0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C29B50>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086D006E20>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C29C10>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086D0067C0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C29B50>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086D006CA0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C29C10>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086D006E20>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C29B50>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086D0067C0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C29C10>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086D006CA0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C29B50>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086D006E20>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C29B50>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C29C10>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C29C10>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C29B50>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C29B50>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C29C10>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C29C10>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C29B50>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C29B50>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C29C10>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C29C10>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C29B50>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C29B50>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C29C10>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E47D730>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C29C10>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C29B50>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E47DEE0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C29B50>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C29C10>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E47D730>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C29C10>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C29B50>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E47DEE0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C29B50>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C29C10>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E47D730>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C29C10>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E470B80>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C29B50>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E470EE0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C29C10>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E470B80>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C29B50>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E470EE0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C29C10>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E470B80>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C29B50>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E470EE0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C29C10>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E470B80>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C29B50>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E470B80>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E470B80>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C29C10>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E470B80>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E470EE0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C29B50>. Consider rewriting this model with the Functional API.
# Adding images:  86%|████████████████████████████████████████████████████▋        | 8010/9268 [00:01<00:00, 2709.06it/s]
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E470B80>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086D006E20>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20857744C70>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E470B80>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E470EE0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086D006E20>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20857744C70>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E470EE0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E470B80>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086D006E20>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20857744C70>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E470B80>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E470EE0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086D006E20>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20857744C70>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E470EE0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E470B80>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086D006E20>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20857744C70>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E470B80>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E470EE0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086D006E20>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20857744C70>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E470EE0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E470B80>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086D006E20>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20857744C70>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E470B80>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E470EE0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086D006E20>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20857744C70>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E470EE0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E470B80>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086D006E20>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20857744C70>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E470B80>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E48FC70>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E470EE0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E48FC70>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E48FC70>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E470B80>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E48FC70>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E48F340>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E470B80>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E48F340>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E48FC70>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E470EE0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E48FC70>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E48F340>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E470B80>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E491E80>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E491E80>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E48FC70>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E491E80>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E491B50>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E48FC70>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E491B50>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E491E80>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E48F340>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E491E80>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E491B50>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E48FC70>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E491B50>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E491E80>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E487DF0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E48F340>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E487DF0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E487F70>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E48FC70>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E487F70>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E487DF0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E48F340>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E487DF0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E487F70>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E48FC70>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E487F70>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E487DF0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E48F340>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E490820>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E490AF0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E487F70>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E490AF0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E490820>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E487DF0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E490820>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E490AF0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E487F70>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E490AF0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E490820>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E487DF0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E490820>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E490AF0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E487F70>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E490AF0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E490820>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E487DF0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E490820>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E490AF0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E487F70>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E490AF0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E490820>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E487DF0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E490820>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E490AF0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E487F70>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E490AF0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E493AC0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E490820>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E4936D0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E490AF0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E4936D0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E490820>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E493AC0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E490AF0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E493AC0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E490820>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E4936D0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E490AF0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E493AC0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E490820>. Consider rewriting this model with the Functional API.
# ...
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E499760>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E4959D0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E4A25B0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E49ADC0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E49C4C0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E49C4C0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E49F370>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E49FA90>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E48FA90>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E48FA90>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E495A60>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E487F70>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E4997F0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E48FA90>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086D006E50>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086D006E50>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E49BD00>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086D006E50>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E487F70>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E49ADC0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086D006E50>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E496C10>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E496820>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E487F70>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E491820>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E49ADC0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086D006E50>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086D006E50>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E487F70>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E491820>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E4997F0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E4997F0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E495430>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E49ADC0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E49ADC0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E4700D0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E4997F0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086D006E50>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E493E80>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E496C10>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086D00A7C0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086D00A7C0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E49C430>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E49ADC0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E49ADC0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E49B520>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E499850>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E499550>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E49ADC0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E496C10>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E496C10>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E48DF70>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E496C10>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E49C430>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E49C430>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E499550>. Consider rewriting this model with the Functional API.
# Adding images: 100%|█████████████████████████████████████████████████████████████▉| 9254/9268 [00:04<00:00, 601.44it/s]
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E493E80>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E49BC40>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E48DF70>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E49C430>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E499550>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E4700D0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E499550>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E4700D0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E49B5E0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E49B5E0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E49B520>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E49CA60>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E49FEB0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E49BC40>. Consider rewriting this model with the Functional API.
# Adding images: 100%|█████████████████████████████████████████████████████████████| 9268/9268 [00:04<00:00, 2147.10it/s]
# getImage COMPLETED!
# Adding images: 100%|█████████████████████████████████████████████████████████████| 1980/1980 [00:00<00:00, 4884.46it/s]
# getImage COMPLETED!

# %%
x2_train = train_task2['ImageName']
y2_train = train_task2['cellType']
print("Original Dataset:\n",y2_train.value_counts())

#Generate sample
x2_train, y2_train = GenerateSample(x2_train,y2_train)
print("Sampled Dataset:\n",y2_train.value_counts())
x2_train = GetImage(x2_train)

x2_test = val_task2['ImageName']
x2_test = GetImage(x2_test)

y2_test = val_task2['cellType']
# Out:
# Original Dataset:
#  2    3282
# 1    2036
# 0    1507
# 3    1091
# Name: cellType, dtype: int64
# Sampled Dataset:
#  1    3282
# 3    3282
# 2    3282
# 0    3282
# Name: cellType, dtype: int64
# Adding images:  59%|███████████████████████████████████▎                        | 7727/13128 [00:01<00:01, 3500.66it/s]
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C39E80>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C393A0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x208576B03D0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20852EA4610>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C393A0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C39E80>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x208576B03D0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20852EA4610>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C39E80>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C39E80>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x208577403A0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C34A90>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x208576B03D0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086D006E50>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086D006E50>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20857720EE0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E49A0A0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20857720400>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C39E80>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C39E80>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C39E80>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C39E80>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C39E80>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E49AAC0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C39E80>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20857720400>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C39E80>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086D006E50>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E49AAC0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E49AAC0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E49CA60>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E49CA60>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086D009550>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E49CA60>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C34A90>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C34A90>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20857720400>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E48DAC0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E49CA60>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086D009B20>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E48DAC0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086D006E50>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C34A90>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20852EA4610>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E49CA60>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E48DAC0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086D006E50>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C34A90>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20852EA4610>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E49CA60>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E48DAC0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086D006E50>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086D006E50>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20852EA4610>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E49CA60>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E48DAC0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C34A90>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086D006E50>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20852EA4610>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E49CA60>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E48DAC0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C34A90>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C34A90>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086D006E50>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086D006E50>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E49A550>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E47D730>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C34A90>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086D006E50>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20852EA4610>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20852EA4610>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E49CA60>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E49CA60>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C34A90>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C34A90>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C34A90>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E496D90>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20852EA4610>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20852EA4610>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E47D730>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20857740F40>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20857740F40>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20855678D30>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086D006E50>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20852EA4610>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E47D730>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C34A90>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C34A90>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E49F370>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E49AAC0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E49F370>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20857720400>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20855678D30>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E47D730>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E49B2B0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E49B2B0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E49B2B0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E49B2B0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E49B2B0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E49BC10>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E47D730>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E47D730>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E4A2850>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20857740F40>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E48CE50>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086D009BE0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20857720400>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E49A7F0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086D009BE0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086D009BE0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E4A2610>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E49BD00>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086D009B80>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086D009B80>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20857740F40>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E4A3F10>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E49FCA0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20857740F40>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E49BD90>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E49BD90>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E4A2610>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E49B490>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20852EA4610>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x208576B03D0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20852EA4610>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20852EA4610>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20852EA4610>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20855678DC0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20855678DC0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20855678E50>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E49AAC0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20857720400>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20857720400>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E496820>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E48FA90>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E48FA90>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E48CAF0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E48CAF0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E49F370>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20855678DC0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20855678DC0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20855678DC0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E4A3E50>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E48FA90>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20855678DC0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E499760>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E499760>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E48D9A0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20852EA4610>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E499760>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E499760>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E499760>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E499760>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E4953A0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20852EA4610>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E49B7F0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E49BD00>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E4953A0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E4953A0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C34A90>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C34A90>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E49A0A0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E49A0A0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E49A490>. Consider rewriting this model with the Functional API.
# Adding images:  62%|████████████████████████████████████▉                       | 8080/13128 [00:02<00:02, 2157.26it/s]
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20855678E50>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086D009400>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C393A0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C393A0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20855678E50>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20855678EE0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20852EA4610>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C34A90>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C34A90>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086D009430>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086D009430>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086D0093D0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E49A490>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E48FA90>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086D0093D0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086D0093D0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086D0093D0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086D009430>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E49F370>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E48FA90>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20855678EE0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20855678E50>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20852EA4610>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E49A490>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E49A490>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E49A550>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E499850>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E4A2A60>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E499850>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E499850>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E49A0A0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C393A0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C393A0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C34A90>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E49A0A0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E4A27F0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E4953A0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E4953A0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E49A0A0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E49A550>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E48DAC0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E48FA90>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E48DAC0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E48DAC0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E496820>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E49A0A0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E47D730>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E49AAC0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E49AAC0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E48CAF0>. Consider rewriting this model with the Functional API.
# ...
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E499850>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E493B50>. Consider rewriting this model with the Functional API.
# Adding images:  99%|███████████████████████████████████████████████████████████▋| 13061/13128 [00:10<00:00, 631.15it/s]
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E49A550>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E49A550>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E499850>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E499850>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086D009490>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E499850>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E499850>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E4A4160>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20857720EE0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E48C310>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E48C310>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E48C310>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C393A0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E499850>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E4A4160>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E48C310>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086D009130>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E4A4E50>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086D009FA0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C393A0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C393A0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E4A4730>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086D009730>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20858C393A0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E48D9D0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E48D9D0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086D009D30>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086D009D30>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086D009730>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086D009730>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E4A4160>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E4A46D0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E49F370>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E48C310>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E48C310>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E49CA60>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E4A4E50>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E4A4E50>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E48D9D0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086D009730>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086D009D30>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086D009D30>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E48C310>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E48C310>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x208575DF4C0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E499850>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x208577403A0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20855678DC0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x208577403A0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x208575DF4C0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20855678EE0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20852EA4610>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20855678D30>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E48C6D0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E48D9A0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E48D9A0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E499850>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E48CAF0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E48D9A0>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20852EA4610>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E49F370>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086D009730>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086D009A30>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086E49F370>. Consider rewriting this model with the Functional API.
# Adding images: 100%|███████████████████████████████████████████████████████████▉| 13125/13128 [00:10<00:00, 620.69it/s]
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20857720400>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x20855678D30>. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=<PIL.Image.Image image mode=RGB size=27x27 at 0x2086D009730>. Consider rewriting this model with the Functional API.
# Adding images: 100%|███████████████████████████████████████████████████████████| 13128/13128 [00:10<00:00, 1247.41it/s]
# getImage COMPLETED!
# Adding images: 100%|█████████████████████████████████████████████████████████████| 1980/1980 [00:00<00:00, 5312.17it/s]
# getImage COMPLETED!

# %%
print("TASK 1 SHAPE")
print("TRAIN SHAPE:")
print("x1 shape:", x1_train.shape)
print("y1 shape:", y1_train.shape)
print("TEST SHAPE:")
print("x1 shape:", x1_test.shape)
print("y1 shape:", y1_test.shape)

print("\n")

print("TASK 2 SHAPE")
print("x1 shape:", x1_train.shape)
print("y1 shape:", y1_train.shape)
print("TEST SHAPE:")
print("x1 shape:", x1_test.shape)
print("y1 shape:", y1_test.shape)
# Out:
# TASK 1 SHAPE
# TRAIN SHAPE:
# x1 shape: (9268, 27, 27, 3)
# y1 shape: (9268,)
# TEST SHAPE:
# x1 shape: (1980, 27, 27, 3)
# y1 shape: (1980,)
#
#
# TASK 2 SHAPE
# x1 shape: (9268, 27, 27, 3)
# y1 shape: (9268,)
# TEST SHAPE:
# x1 shape: (1980, 27, 27, 3)
# y1 shape: (1980,)

# %% [markdown]
# # 3.3. Data Augmentation Technique

# %% [markdown]
# Lý do dùng ??

# %%
plt.axis('off')
plt.imshow(x1_train[2580].astype(np.uint8))

# %%
plt.imshow((x1_train)[7916].astype(np.uint8))

# %%
# Apply loc to double check that only cellType = 2 is Cancerous
#main_data.loc[(main_data['cellType'] == 2) & (main_data['isCancerous'] == 1)]

# %%
# Create datagen
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator()

# train_datagen1 = datagen.flow(train_img_X1, train_mod_Y1, batch_size=16, shuffle=True)
data_train1 = datagen.flow(x1_train, y1_train, batch_size=16, shuffle=True)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D , Flatten, BatchNormalization, Dropout
from tensorflow.keras.regularizers import l2

# %% [markdown]
# model = Sequential()
# model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=(27, 27, 3)))
# model.add(BatchNormalization())
# model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
# model.add(BatchNormalization())
# model.add(MaxPooling2D((2, 2)))
# model.add(Dropout(0.2))
#
# model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', kernel_regularizer=l2(l=0.01), padding='same'))
# model.add(BatchNormalization())
# model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', kernel_regularizer=l2(l=0.01), padding='same'))
# model.add(BatchNormalization())
# model.add(MaxPooling2D((2, 2)))
# model.add(Dropout(0.3))
#
# model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', kernel_regularizer=l2(l=0.01), padding='same'))
# model.add(BatchNormalization())
# model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', kernel_regularizer=l2(l=0.01), padding='same'))
# model.add(BatchNormalization())
# model.add(MaxPooling2D((2, 2)))
# model.add(Dropout(0.4))
#
# model.add(Flatten())
# model.add(Dense(512, kernel_regularizer=l2(l=0.01), activation='relu'))
# model.add(BatchNormalization())
# model.add(Dropout(0.2))
# model.add(Dense(512, kernel_regularizer=l2(l=0.01), activation='relu'))
# model.add(BatchNormalization())
# model.add(Dropout(0.2))
# model.add(Dense(4, activation='softmax'))
#
# model.summary()

# %% [markdown]
# # non-stack model

# %% [markdown]
# model = Sequential()
# model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=(27, 27, 3)))
# model.add(BatchNormalization())
# model.add(MaxPooling2D((2, 2)))
# model.add(Dropout(0.2))
#
# model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', kernel_regularizer=l2(l=0.01), padding='same'))
# model.add(BatchNormalization())
# model.add(MaxPooling2D((2, 2)))
# model.add(Dropout(0.3))
#
# model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', kernel_regularizer=l2(l=0.01), padding='same'))
# model.add(BatchNormalization())
# model.add(MaxPooling2D((2, 2)))
# model.add(Dropout(0.4))
#
# model.add(Flatten())
# model.add(Dense(512, kernel_regularizer=l2(l=0.01), activation='relu'))
# model.add(BatchNormalization())
# model.add(Dropout(0.2))
# model.add(Dense(4, activation='softmax'))
#
# model.summary()

# %% [markdown]
# # Lower filter model

# %%
model = Sequential()
model.add(Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=(27, 27, 3)))
model.add(BatchNormalization())
model.add(Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.2))

model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', kernel_regularizer=l2(l=0.01), padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', kernel_regularizer=l2(l=0.01), padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.3))

model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', kernel_regularizer=l2(l=0.01), padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', kernel_regularizer=l2(l=0.01), padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.4))

model.add(Flatten())
model.add(Dense(512, kernel_regularizer=l2(l=0.01), activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.2))
model.add(Dense(512, kernel_regularizer=l2(l=0.01), activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.2))
model.add(Dense(4, activation='softmax'))

model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 27, 27, 16)        448
#
#  batch_normalization_4 (Batc  (None, 27, 27, 16)       64
#  hNormalization)
#
#  conv2d_4 (Conv2D)           (None, 27, 27, 16)        2320
#
#  batch_normalization_5 (Batc  (None, 27, 27, 16)       64
#  hNormalization)
#
#  max_pooling2d_3 (MaxPooling  (None, 13, 13, 16)       0
#  2D)
#
#  dropout_4 (Dropout)         (None, 13, 13, 16)        0
#
#  conv2d_5 (Conv2D)           (None, 13, 13, 32)        4640
#
#  batch_normalization_6 (Batc  (None, 13, 13, 32)       128
#  hNormalization)
#
#  conv2d_6 (Conv2D)           (None, 13, 13, 32)        9248
#
#  batch_normalization_7 (Batc  (None, 13, 13, 32)       128
#  hNormalization)
#
#  max_pooling2d_4 (MaxPooling  (None, 6, 6, 32)         0
#  2D)
#
#  dropout_5 (Dropout)         (None, 6, 6, 32)          0
#
#  conv2d_7 (Conv2D)           (None, 6, 6, 64)          18496
#
#  batch_normalization_8 (Batc  (None, 6, 6, 64)         256
#  hNormalization)
#
#  conv2d_8 (Conv2D)           (None, 6, 6, 64)          36928
#
#  batch_normalization_9 (Batc  (None, 6, 6, 64)         256
#  hNormalization)
#
#  max_pooling2d_5 (MaxPooling  (None, 3, 3, 64)         0
#  2D)
#
#  dropout_6 (Dropout)         (None, 3, 3, 64)          0
#
#  flatten_1 (Flatten)         (None, 576)               0
#
#  dense_2 (Dense)             (None, 512)               295424
#
#  batch_normalization_10 (Bat  (None, 512)              2048
#  chNormalization)
#
#  dropout_7 (Dropout)         (None, 512)               0
#
#  dense_3 (Dense)             (None, 512)               262656
#
#  batch_normalization_11 (Bat  (None, 512)              2048
#  chNormalization)
#
#  dropout_8 (Dropout)         (None, 512)               0
#
#  dense_4 (Dense)             (None, 4)                 2052
#
# =================================================================
# Total params: 637,204
# Trainable params: 634,708
# Non-trainable params: 2,496
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import Adam
opt = Adam(lr=0.0005, beta_1=0.4, beta_2=0.444, decay=1.0e-6, amsgrad=True)
model.compile(optimizer=opt , loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
early = EarlyStopping(monitor='accuracy', min_delta=0.001, patience=10, verbose=1, mode='auto')
#reduce learning rate when the metric is not improving
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=np.sqrt(0.1), cooldown=0, patience=6, min_lr=0.5e-15) 

EPOCHS = 500
BATCH_SIZE = 32

import time
start_time = time.time()

history = model.fit(data_train1, 
                    validation_data=(x1_test, y1_test), 
                    batch_size=BATCH_SIZE, 
                    epochs=EPOCHS, 
                    verbose=1,
                    callbacks=[reduce_lr, early])

print("---  Training time in seconds ---%s " % (time.time() - start_time))
# Out:
# Epoch 1/500
# 580/580 [==============================] - 16s 25ms/step - loss: 2.6787 - accuracy: 0.8774 - val_loss: 2.5456 - val_accuracy: 0.7596 - lr: 5.0000e-04
# Epoch 2/500
# 580/580 [==============================] - 14s 25ms/step - loss: 2.1007 - accuracy: 0.8781 - val_loss: 1.9898 - val_accuracy: 0.8232 - lr: 5.0000e-04
# Epoch 3/500
# 580/580 [==============================] - 14s 24ms/step - loss: 1.7385 - accuracy: 0.8797 - val_loss: 1.6334 - val_accuracy: 0.8621 - lr: 5.0000e-04
# Epoch 4/500
# 580/580 [==============================] - 14s 24ms/step - loss: 1.4745 - accuracy: 0.8827 - val_loss: 1.4075 - val_accuracy: 0.8667 - lr: 5.0000e-04
# Epoch 5/500
# 580/580 [==============================] - 14s 24ms/step - loss: 1.2659 - accuracy: 0.8872 - val_loss: 1.2050 - val_accuracy: 0.8833 - lr: 5.0000e-04
# Epoch 6/500
# 580/580 [==============================] - 14s 23ms/step - loss: 1.1084 - accuracy: 0.8944 - val_loss: 1.1480 - val_accuracy: 0.8621 - lr: 5.0000e-04
# Epoch 7/500
# 580/580 [==============================] - 14s 24ms/step - loss: 0.9888 - accuracy: 0.8919 - val_loss: 1.0496 - val_accuracy: 0.8303 - lr: 5.0000e-04
# Epoch 8/500
# 580/580 [==============================] - 13s 23ms/step - loss: 0.8912 - accuracy: 0.8954 - val_loss: 0.8645 - val_accuracy: 0.8934 - lr: 5.0000e-04
# Epoch 9/500
# 580/580 [==============================] - 14s 23ms/step - loss: 0.8159 - accuracy: 0.8925 - val_loss: 0.9044 - val_accuracy: 0.8510 - lr: 5.0000e-04
# Epoch 10/500
# 580/580 [==============================] - 14s 23ms/step - loss: 0.7465 - accuracy: 0.8971 - val_loss: 0.7905 - val_accuracy: 0.8682 - lr: 5.0000e-04
# Epoch 11/500
# 580/580 [==============================] - 14s 23ms/step - loss: 0.6943 - accuracy: 0.8962 - val_loss: 0.7525 - val_accuracy: 0.8424 - lr: 5.0000e-04
# Epoch 12/500
# 580/580 [==============================] - 14s 23ms/step - loss: 0.6328 - accuracy: 0.9052 - val_loss: 0.7011 - val_accuracy: 0.8545 - lr: 5.0000e-04
# Epoch 13/500
# 580/580 [==============================] - 14s 24ms/step - loss: 0.6013 - accuracy: 0.9050 - val_loss: 0.6017 - val_accuracy: 0.9000 - lr: 5.0000e-04
# Epoch 14/500
# 580/580 [==============================] - 14s 25ms/step - loss: 0.5652 - accuracy: 0.9068 - val_loss: 0.5887 - val_accuracy: 0.8864 - lr: 5.0000e-04
# Epoch 15/500
# 580/580 [==============================] - 14s 24ms/step - loss: 0.5342 - accuracy: 0.9044 - val_loss: 0.5731 - val_accuracy: 0.8763 - lr: 5.0000e-04
# Epoch 16/500
# 580/580 [==============================] - 14s 24ms/step - loss: 0.5172 - accuracy: 0.9045 - val_loss: 0.5302 - val_accuracy: 0.8975 - lr: 5.0000e-04
# Epoch 17/500
# 580/580 [==============================] - 14s 24ms/step - loss: 0.4897 - accuracy: 0.9095 - val_loss: 0.4889 - val_accuracy: 0.9116 - lr: 5.0000e-04
# Epoch 18/500
# 580/580 [==============================] - 14s 24ms/step - loss: 0.4723 - accuracy: 0.9086 - val_loss: 0.4830 - val_accuracy: 0.9020 - lr: 5.0000e-04
# Epoch 19/500
# 580/580 [==============================] - 14s 24ms/step - loss: 0.4540 - accuracy: 0.9112 - val_loss: 0.4655 - val_accuracy: 0.9005 - lr: 5.0000e-04
# Epoch 20/500
# 580/580 [==============================] - 14s 24ms/step - loss: 0.4322 - accuracy: 0.9134 - val_loss: 0.5072 - val_accuracy: 0.8823 - lr: 5.0000e-04
# Epoch 21/500
# 580/580 [==============================] - 14s 23ms/step - loss: 0.4138 - accuracy: 0.9178 - val_loss: 0.4830 - val_accuracy: 0.8939 - lr: 5.0000e-04
# Epoch 22/500
# 580/580 [==============================] - 14s 25ms/step - loss: 0.4076 - accuracy: 0.9179 - val_loss: 0.4197 - val_accuracy: 0.9157 - lr: 5.0000e-04
# Epoch 23/500
# 580/580 [==============================] - 15s 26ms/step - loss: 0.3904 - accuracy: 0.9212 - val_loss: 0.5010 - val_accuracy: 0.8722 - lr: 5.0000e-04
# Epoch 24/500
# 580/580 [==============================] - 14s 24ms/step - loss: 0.3798 - accuracy: 0.9222 - val_loss: 0.4448 - val_accuracy: 0.8985 - lr: 5.0000e-04
# Epoch 25/500
# 580/580 [==============================] - 14s 24ms/step - loss: 0.3695 - accuracy: 0.9240 - val_loss: 0.3985 - val_accuracy: 0.9162 - lr: 5.0000e-04
# Epoch 26/500
# 580/580 [==============================] - 14s 24ms/step - loss: 0.3762 - accuracy: 0.9222 - val_loss: 0.4149 - val_accuracy: 0.9106 - lr: 5.0000e-04
# Epoch 27/500
# 580/580 [==============================] - 14s 24ms/step - loss: 0.3564 - accuracy: 0.9223 - val_loss: 0.4257 - val_accuracy: 0.9076 - lr: 5.0000e-04
# Epoch 28/500
# 580/580 [==============================] - 14s 24ms/step - loss: 0.3545 - accuracy: 0.9245 - val_loss: 0.4231 - val_accuracy: 0.8990 - lr: 5.0000e-04
# Epoch 29/500
# 580/580 [==============================] - 14s 24ms/step - loss: 0.3385 - accuracy: 0.9305 - val_loss: 0.4082 - val_accuracy: 0.9101 - lr: 5.0000e-04
# Epoch 30/500
# 580/580 [==============================] - 14s 25ms/step - loss: 0.3387 - accuracy: 0.9282 - val_loss: 0.3850 - val_accuracy: 0.9167 - lr: 5.0000e-04
# Epoch 31/500
# 580/580 [==============================] - 14s 24ms/step - loss: 0.3374 - accuracy: 0.9259 - val_loss: 0.4133 - val_accuracy: 0.9020 - lr: 5.0000e-04
# Epoch 32/500
# 580/580 [==============================] - 14s 25ms/step - loss: 0.3310 - accuracy: 0.9301 - val_loss: 0.3927 - val_accuracy: 0.9040 - lr: 5.0000e-04
# Epoch 33/500
# 580/580 [==============================] - 14s 25ms/step - loss: 0.3261 - accuracy: 0.9325 - val_loss: 0.3828 - val_accuracy: 0.9035 - lr: 5.0000e-04
# Epoch 34/500
# 580/580 [==============================] - 14s 25ms/step - loss: 0.3156 - accuracy: 0.9352 - val_loss: 0.3783 - val_accuracy: 0.9146 - lr: 5.0000e-04
# Epoch 35/500
# 580/580 [==============================] - 14s 24ms/step - loss: 0.3137 - accuracy: 0.9349 - val_loss: 0.3549 - val_accuracy: 0.9141 - lr: 5.0000e-04
# Epoch 36/500
# 580/580 [==============================] - 14s 25ms/step - loss: 0.3127 - accuracy: 0.9339 - val_loss: 0.3716 - val_accuracy: 0.9152 - lr: 5.0000e-04
# Epoch 37/500
# 580/580 [==============================] - 14s 25ms/step - loss: 0.2980 - accuracy: 0.9384 - val_loss: 0.4062 - val_accuracy: 0.9010 - lr: 5.0000e-04
# Epoch 38/500
# 580/580 [==============================] - 14s 25ms/step - loss: 0.3035 - accuracy: 0.9374 - val_loss: 0.3668 - val_accuracy: 0.9121 - lr: 5.0000e-04
# Epoch 39/500
# 580/580 [==============================] - 14s 25ms/step - loss: 0.2900 - accuracy: 0.9395 - val_loss: 0.3752 - val_accuracy: 0.9020 - lr: 5.0000e-04
# Epoch 40/500
# 580/580 [==============================] - 14s 25ms/step - loss: 0.2909 - accuracy: 0.9393 - val_loss: 0.3552 - val_accuracy: 0.9187 - lr: 5.0000e-04
# Epoch 41/500
# 580/580 [==============================] - 14s 25ms/step - loss: 0.2936 - accuracy: 0.9371 - val_loss: 0.3428 - val_accuracy: 0.9212 - lr: 5.0000e-04
# Epoch 42/500
# 580/580 [==============================] - 14s 24ms/step - loss: 0.2766 - accuracy: 0.9428 - val_loss: 0.4159 - val_accuracy: 0.8919 - lr: 5.0000e-04
# Epoch 43/500
# 580/580 [==============================] - 40s 69ms/step - loss: 0.2836 - accuracy: 0.9414 - val_loss: 0.3690 - val_accuracy: 0.9091 - lr: 5.0000e-04
# Epoch 44/500
# 580/580 [==============================] - 35s 59ms/step - loss: 0.2797 - accuracy: 0.9404 - val_loss: 0.3588 - val_accuracy: 0.9091 - lr: 5.0000e-04
# Epoch 45/500
# 580/580 [==============================] - 21s 36ms/step - loss: 0.2805 - accuracy: 0.9448 - val_loss: 0.3486 - val_accuracy: 0.9091 - lr: 5.0000e-04
# Epoch 46/500
# 580/580 [==============================] - 16s 28ms/step - loss: 0.2747 - accuracy: 0.9444 - val_loss: 0.3506 - val_accuracy: 0.9096 - lr: 5.0000e-04
# Epoch 47/500
# 580/580 [==============================] - 15s 25ms/step - loss: 0.2667 - accuracy: 0.9469 - val_loss: 0.3406 - val_accuracy: 0.9207 - lr: 5.0000e-04
# Epoch 48/500
# 580/580 [==============================] - 15s 25ms/step - loss: 0.2693 - accuracy: 0.9466 - val_loss: 0.3319 - val_accuracy: 0.9273 - lr: 5.0000e-04
# Epoch 49/500
# 580/580 [==============================] - 15s 26ms/step - loss: 0.2676 - accuracy: 0.9464 - val_loss: 0.3540 - val_accuracy: 0.9162 - lr: 5.0000e-04
# Epoch 50/500
# 580/580 [==============================] - 14s 25ms/step - loss: 0.2548 - accuracy: 0.9512 - val_loss: 0.3822 - val_accuracy: 0.9111 - lr: 5.0000e-04
# Epoch 51/500
# 580/580 [==============================] - 14s 24ms/step - loss: 0.2574 - accuracy: 0.9480 - val_loss: 0.3268 - val_accuracy: 0.9323 - lr: 5.0000e-04
# Epoch 52/500
# 580/580 [==============================] - 14s 24ms/step - loss: 0.2612 - accuracy: 0.9512 - val_loss: 0.3636 - val_accuracy: 0.9141 - lr: 5.0000e-04
# Epoch 53/500
# 580/580 [==============================] - 14s 24ms/step - loss: 0.2638 - accuracy: 0.9492 - val_loss: 0.3646 - val_accuracy: 0.9091 - lr: 5.0000e-04
# Epoch 54/500
# 580/580 [==============================] - 14s 25ms/step - loss: 0.2401 - accuracy: 0.9548 - val_loss: 0.3267 - val_accuracy: 0.9237 - lr: 5.0000e-04
# Epoch 55/500
# 580/580 [==============================] - 15s 26ms/step - loss: 0.2573 - accuracy: 0.9478 - val_loss: 0.3579 - val_accuracy: 0.9086 - lr: 5.0000e-04
# Epoch 56/500
# 580/580 [==============================] - 14s 24ms/step - loss: 0.2424 - accuracy: 0.9548 - val_loss: 0.3643 - val_accuracy: 0.9152 - lr: 5.0000e-04
# Epoch 57/500
# 580/580 [==============================] - 14s 24ms/step - loss: 0.2421 - accuracy: 0.9540 - val_loss: 0.3736 - val_accuracy: 0.9126 - lr: 5.0000e-04
# Epoch 58/500
# 580/580 [==============================] - 15s 25ms/step - loss: 0.2290 - accuracy: 0.9608 - val_loss: 0.3250 - val_accuracy: 0.9268 - lr: 5.0000e-04
# Epoch 59/500
# 580/580 [==============================] - 15s 25ms/step - loss: 0.2391 - accuracy: 0.9536 - val_loss: 0.3524 - val_accuracy: 0.9202 - lr: 5.0000e-04
# Epoch 60/500
# 580/580 [==============================] - 15s 25ms/step - loss: 0.2386 - accuracy: 0.9536 - val_loss: 0.3394 - val_accuracy: 0.9146 - lr: 5.0000e-04
# Epoch 61/500
# 580/580 [==============================] - 14s 25ms/step - loss: 0.2276 - accuracy: 0.9577 - val_loss: 0.3266 - val_accuracy: 0.9217 - lr: 5.0000e-04
# Epoch 62/500
# 580/580 [==============================] - 14s 24ms/step - loss: 0.2279 - accuracy: 0.9580 - val_loss: 0.3574 - val_accuracy: 0.9192 - lr: 5.0000e-04
# Epoch 63/500
# 580/580 [==============================] - 14s 24ms/step - loss: 0.2234 - accuracy: 0.9572 - val_loss: 0.3920 - val_accuracy: 0.9076 - lr: 5.0000e-04
# Epoch 64/500
# 580/580 [==============================] - 14s 24ms/step - loss: 0.2315 - accuracy: 0.9557 - val_loss: 0.3648 - val_accuracy: 0.9126 - lr: 5.0000e-04
# Epoch 65/500
# 580/580 [==============================] - 14s 24ms/step - loss: 0.2098 - accuracy: 0.9637 - val_loss: 0.3319 - val_accuracy: 0.9283 - lr: 1.5811e-04
# Epoch 66/500
# 580/580 [==============================] - 14s 24ms/step - loss: 0.2032 - accuracy: 0.9681 - val_loss: 0.3385 - val_accuracy: 0.9253 - lr: 1.5811e-04
# Epoch 67/500
# 580/580 [==============================] - 14s 24ms/step - loss: 0.1969 - accuracy: 0.9680 - val_loss: 0.3370 - val_accuracy: 0.9227 - lr: 1.5811e-04
# Epoch 68/500
# 580/580 [==============================] - 14s 24ms/step - loss: 0.1915 - accuracy: 0.9710 - val_loss: 0.3428 - val_accuracy: 0.9207 - lr: 1.5811e-04
# Epoch 69/500
# 580/580 [==============================] - 14s 24ms/step - loss: 0.1960 - accuracy: 0.9681 - val_loss: 0.3540 - val_accuracy: 0.9157 - lr: 1.5811e-04
# Epoch 70/500
# 580/580 [==============================] - 14s 24ms/step - loss: 0.1885 - accuracy: 0.9719 - val_loss: 0.3489 - val_accuracy: 0.9258 - lr: 1.5811e-04
# Epoch 71/500
# 580/580 [==============================] - 14s 24ms/step - loss: 0.1818 - accuracy: 0.9737 - val_loss: 0.3496 - val_accuracy: 0.9273 - lr: 5.0000e-05
# Epoch 72/500
# 580/580 [==============================] - 14s 24ms/step - loss: 0.1845 - accuracy: 0.9718 - val_loss: 0.3350 - val_accuracy: 0.9263 - lr: 5.0000e-05
# Epoch 73/500
# 580/580 [==============================] - 14s 24ms/step - loss: 0.1844 - accuracy: 0.9723 - val_loss: 0.3356 - val_accuracy: 0.9263 - lr: 5.0000e-05
# Epoch 74/500
# 580/580 [==============================] - 14s 24ms/step - loss: 0.1804 - accuracy: 0.9733 - val_loss: 0.3367 - val_accuracy: 0.9313 - lr: 5.0000e-05
# Epoch 75/500
# 580/580 [==============================] - 14s 24ms/step - loss: 0.1774 - accuracy: 0.9735 - val_loss: 0.3402 - val_accuracy: 0.9242 - lr: 5.0000e-05
# Epoch 76/500
# 580/580 [==============================] - 14s 24ms/step - loss: 0.1794 - accuracy: 0.9749 - val_loss: 0.3444 - val_accuracy: 0.9237 - lr: 5.0000e-05
# Epoch 77/500
# 580/580 [==============================] - 14s 24ms/step - loss: 0.1825 - accuracy: 0.9729 - val_loss: 0.3442 - val_accuracy: 0.9253 - lr: 1.5811e-05
# Epoch 78/500
# 580/580 [==============================] - 14s 24ms/step - loss: 0.1688 - accuracy: 0.9790 - val_loss: 0.3405 - val_accuracy: 0.9283 - lr: 1.5811e-05
# Epoch 79/500
# 580/580 [==============================] - 14s 24ms/step - loss: 0.1730 - accuracy: 0.9767 - val_loss: 0.3529 - val_accuracy: 0.9237 - lr: 1.5811e-05
# Epoch 80/500
# 580/580 [==============================] - 14s 24ms/step - loss: 0.1797 - accuracy: 0.9753 - val_loss: 0.3435 - val_accuracy: 0.9268 - lr: 1.5811e-05
# Epoch 81/500
# 580/580 [==============================] - 14s 24ms/step - loss: 0.1735 - accuracy: 0.9752 - val_loss: 0.3448 - val_accuracy: 0.9227 - lr: 1.5811e-05
# Epoch 82/500
# 580/580 [==============================] - 14s 24ms/step - loss: 0.1756 - accuracy: 0.9750 - val_loss: 0.3444 - val_accuracy: 0.9242 - lr: 1.5811e-05
# Epoch 83/500
# 580/580 [==============================] - 14s 24ms/step - loss: 0.1674 - accuracy: 0.9789 - val_loss: 0.3391 - val_accuracy: 0.9273 - lr: 5.0000e-06
# Epoch 84/500
# 580/580 [==============================] - 14s 24ms/step - loss: 0.1722 - accuracy: 0.9762 - val_loss: 0.3433 - val_accuracy: 0.9268 - lr: 5.0000e-06
# Epoch 85/500
# 580/580 [==============================] - 14s 24ms/step - loss: 0.1726 - accuracy: 0.9774 - val_loss: 0.3410 - val_accuracy: 0.9263 - lr: 5.0000e-06
# Epoch 86/500
# 580/580 [==============================] - 14s 24ms/step - loss: 0.1788 - accuracy: 0.9746 - val_loss: 0.3400 - val_accuracy: 0.9273 - lr: 5.0000e-06
# Epoch 87/500
# 580/580 [==============================] - 14s 24ms/step - loss: 0.1693 - accuracy: 0.9781 - val_loss: 0.3405 - val_accuracy: 0.9263 - lr: 5.0000e-06
# Epoch 88/500
# 580/580 [==============================] - 14s 24ms/step - loss: 0.1784 - accuracy: 0.9738 - val_loss: 0.3405 - val_accuracy: 0.9268 - lr: 5.0000e-06
# Epoch 88: early stopping
# ---  Training time in seconds ---1293.4313695430756

# %%
model.save("task1_11.5.2022_lowerlayer")
# Out:
# INFO:tensorflow:Assets written to: task1_11.5.2022_lowerlayer\assets

# %%
scores = model.evaluate(x1_test, y1_test, verbose=1)
print('Validation loss:', scores[0])
print('Validation accuracy:', scores[1])
print('Max Validation accuracy:', max(history.history['accuracy']))

# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()
# Out:
# 62/62 [==============================] - 1s 9ms/step - loss: 0.3405 - accuracy: 0.9268
# Validation loss: 0.3404712975025177
# Validation accuracy: 0.9267676472663879
# Max Validation accuracy: 0.978959858417511

# %%
from sklearn.metrics import classification_report
model = keras.models.load_model('task1_10.5.2022')
predict=model.predict(x1_test)
classes=np.argmax(predict,axis=1)

print(classification_report(y1_test, classes))
model = keras.models.load_model('task1_11.5.2022_lowerlayer')
predict=model.predict(x1_test)
classes=np.argmax(predict,axis=1)

print(classification_report(y1_test, classes))
model = keras.models.load_model('task1_11.5.2022_nonstack')
predict=model.predict(x1_test)
classes=np.argmax(predict,axis=1)

print(classification_report(y1_test, classes))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.92      0.94      1183
#            1       0.89      0.93      0.91       797
#
#     accuracy                           0.93      1980
#    macro avg       0.92      0.93      0.92      1980
# weighted avg       0.93      0.93      0.93      1980
#
#               precision    recall  f1-score   support
#
#            0       0.96      0.92      0.94      1183
#            1       0.89      0.94      0.91       797
#
#     accuracy                           0.93      1980
#    macro avg       0.92      0.93      0.92      1980
# weighted avg       0.93      0.93      0.93      1980
#
#               precision    recall  f1-score   support
#
#            0       0.95      0.89      0.92      1183
#            1       0.85      0.93      0.89       797
#            2       0.00      0.00      0.00         0
#
#     accuracy                           0.91      1980
#    macro avg       0.60      0.61      0.60      1980
# weighted avg       0.91      0.91      0.91      1980

# %%
for i, image in enumerate(x1_test):
     plt.imshow(image) 
for i in range (20):
    plt.imshow(x1_test[i])
    plt.title("GT-{}, Pred-{}".format(y1_test.tolist()[i], classes[i] ))
    plt.show()

# %%
predict=model.predict(x1_test)
classes=np.argmax(predict,axis=1)

print(classification_report(y1_test, classes))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.92      0.94      1183
#            1       0.89      0.94      0.91       797
#
#     accuracy                           0.93      1980
#    macro avg       0.92      0.93      0.92      1980
# weighted avg       0.93      0.93      0.93      1980
